# %%
#!pip install levenshtein

import Levenshtein as lev
import functools
import numpy as np
import pandas as pd
import pickle
import plotly.express as px
import plotly.graph_objects as go

from ttictoc import tic,toc

# %%
# Dataframe download

with open("df_feat_added_full.pkl","rb") as f:
    df = pickle.load(f)

# %%
# Creating a dictionary, key: sentences count, values: strings of the same num of sentences.
# Levensthein formula will be calculated for each value (list of strings) separately.

class LevenstheinDF:
    
    def __init__(self, df):
        mask = (
            df[['words', 'sentences']].duplicated() == True) & (
            df['sentences'] > 1    
        )
        self.df = df[['name', 'text', 'words', 'sentences', 'verbs_ratio', 'nouns_ratio']][mask]
        self.median_dict = self.get_lev_median()
        self.duplicates = set(self.df['text'].loc[self.df['text'].duplicated(keep=False) == True])
        
    def get_lev_median(self):
        median_dict = dict()
        for i in set(self.df['sentences'].values):
             median_dict[i] = lev.quickmedian(self.df['text'][self.df['sentences'] == i])
        return median_dict 
     
    # Adding median value to the existing dataframe
    def add_to_df(self, x):
        for key, value in self.median_dict.items():
            if x == key:
                return value
    
    # Checking for duplicates and getting ratio
    def check_duplicates(self, x):
        if x[1] in self.duplicates:
            return 0
        else:
            return lev.ratio(x[0], x[1])
            
    # Final ratio calculation    
    def get_ratio(self):
        tic()        
        self.df['median_str'] = self.df['sentences'].apply(self.add_to_df)
        self.df['lev_zip'] = list(zip(self.df['median_str'].values, self.df['text'].values))
        self.df['lev_ratio'] = self.df['lev_zip'].apply(self.check_duplicates)
        elapsed = toc()
        print(f'Time elapsed: {elapsed}')
        return self.df

# %%
leven = LevenstheinDF(df)
compare_df = leven.get_ratio()
# Out:
# Time elapsed: 9.827430000000001

# %%
compare_df
# Out:
#                name                                               text  words  \
# 116    10595647.txt  Spowiedź i rachunek sumienia (dla dorosłych)\n...   4925
# 214    11067484.txt  Aktualności » Ogłoszenia » Intencje i nabożeńs...   1520
# 219    11083031.txt  Spowiedź i rachunek sumienia (dla dorosłych)\n...   4925
# 225    11109586.txt  Prawdę powiedziawszy, modlitwa różańcowa na pi...    465
# 291    11530580.txt  Informacje\nSzczegóły Utworzono: piątek, 03, k...   4754
# ...             ...                                                ...    ...
# 28601  99993801.txt  Św. Jan Paweł II prosił, by modlitwę „Anioł Pa...    564
# 28606  99995793.txt  Dzieje Wielkich Oczu\nNazwa miejscowości wywod...    454
# 28607  99996277.txt  „Wychowanie w czasie sporów w kulturowych” - c...    447
# 28610  99998238.txt  W podziękowaniu za pół wieku posługi organisto...    782
# 28613   9999901.txt  Propozycja - Dzień Życia Konsekrowanego 2023 2...    739
#
#        sentences  verbs_ratio  nouns_ratio  \
# 116          474         0.11         0.26
# 214           85         0.09         0.36
# 219          474         0.11         0.26
# 225           38         0.12         0.24
# 291          292         0.11         0.25
# ...          ...          ...          ...
# 28601         52         0.11         0.25
# 28606         32         0.07         0.33
# 28607         29         0.05         0.40
# 28610         55         0.09         0.28
# 28613         52         0.06         0.35
#
#                                               median_str  \
# 116    Spowiedź i rachunek sumienia (dla dorosłych)\n...
# 214    Aktaarości » rłwszenia oIntenc ei nabożeńs a »...
# 219    Spowiedź i rachunek sumienia (dla dorosłych)\n...
# 225    Szzeo      ik ano  oda    sir i             o ...
# 291    Informacje\nSzczegóły Utworzono: piątek, 03, k...
# ...                                                  ...
# 28601  Dooei a    i aa     oo              e ii      ...
# 28606  Wii           a                               ...
# 28607  Dzio a                                        ...
# 28610  Da oe        w    a i      a  zi      o    ie ...
# 28613  Dooei a    i aa     oo              e ii      ...
#
#                                                  lev_zip  lev_ratio
# 116    (Spowiedź i rachunek sumienia (dla dorosłych)\...   0.999939
# 214    (Aktaarości » rłwszenia oIntenc ei nabożeńs a ...   0.742999
# 219    (Spowiedź i rachunek sumienia (dla dorosłych)\...   0.999969
# 225    (Szzeo      ik ano  oda    sir i             o...   0.309677
# 291    (Informacje\nSzczegóły Utworzono: piątek, 03, ...   0.999967
# ...                                                  ...        ...
# 28601  (Dooei a    i aa     oo              e ii     ...   0.260586
# 28606  (Wii           a                              ...   0.126627
# 28607  (Dzio a                                       ...   0.130550
# 28610  (Da oe        w    a i      a  zi      o    ie...   0.311045
# 28613  (Dooei a    i aa     oo              e ii     ...   0.275671
#
# [8379 rows x 9 columns]

# %%
with open("compare_df.pkl","wb") as f:
    pickle.dump(compare_df, f)

# %%
compare_df['lev_ratio'].describe()
# Out:
# count    8379.000000
# mean        0.287037
# std         0.227713
# min         0.084618
# 25%         0.146610
# 50%         0.186326
# 75%         0.326130
# max         1.000000
# Name: lev_ratio, dtype: float64

# %%
def get_similar(compare_df):
    return compare_df[
        (compare_df['lev_ratio'] > 0.4)
    ].sort_values(by=['lev_ratio', 'text'])

def get_different(compare_df):
    return compare_df[
        (compare_df['lev_ratio'] <= 0.4)
    ].sort_values(by=['lev_ratio', 'text'])

# %%
get_similar(compare_df)
# Out:
#                name                                               text  words  \
# 18282  78856726.txt  Nabożeństwo z koronką do Miłosierdzia Bożego i...    796
# 17052  75300309.txt  Nabożeństwo z koronką do Miłosierdzia Bożego i...    796
# 24957  94794276.txt  Nabożeństwo z koronką do Miłosierdzia Bożego i...    796
# 21171   8654013.txt  Nabożeństwo z koronką do Miłosierdzia Bożego i...    796
# 5544   35268757.txt  Nabożeństwo z koronką do Miłosierdzia Bożego i...    796
# ...             ...                                                ...    ...
# 13259  64030708.txt  XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. Py...   4338
# 21075  86292894.txt  XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. Py...   4338
# 14835  68986119.txt  ZGROMADZENI NA ŚWIĘTEJ WIECZERZY\nList biskupó...   2480
# 26448    973786.txt  ŚW. MARIA MAGDALENA - patronka naszej parafii\...   1585
# 18341  79011063.txt  Śluby Narodu\nSzczegóły Kategoria: DODATKI I C...   5564
#
#        sentences  verbs_ratio  nouns_ratio  \
# 18282         63         0.03         0.17
# 17052         63         0.03         0.17
# 24957         63         0.03         0.17
# 21171         63         0.03         0.17
# 5544          63         0.03         0.17
# ...          ...          ...          ...
# 13259        259         0.11         0.25
# 21075        263         0.11         0.25
# 14835        143         0.10         0.27
# 26448         95         0.11         0.21
# 18341        271         0.09         0.29
#
#                                               median_str  \
# 18282  Biblaż arstww kz kięga: Ew dolia św. aeeuszi  ...
# 17052  Biblaż arstww kz kięga: Ew dolia św. aeeuszi  ...
# 24957  Biblaż arstww kz kięga: Ew dolia św. aeeuszi  ...
# 21171  Biblaż arstww kz kięga: Ew dolia św. aeeuszi  ...
# 5544   Biblaż arstww kz kięga: Ew dolia św. aeeuszi  ...
# ...                                                  ...
# 13259  XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. Py...
# 21075  XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. Py...
# 14835  ZGROMADZENI NA ŚWIĘTEJ WIECZERZY\nList biskupó...
# 26448  ŚW. MARIA MAGDALENA - patronka naszej parafii\...
# 18341  Śluby Narodu\nSzczegóły Kategoria: DODATKI I C...
#
#                                                  lev_zip  lev_ratio
# 18282  (Biblaż arstww kz kięga: Ew dolia św. aeeuszi ...   0.400447
# 17052  (Biblaż arstww kz kięga: Ew dolia św. aeeuszi ...   0.400447
# 24957  (Biblaż arstww kz kięga: Ew dolia św. aeeuszi ...   0.400447
# 21171  (Biblaż arstww kz kięga: Ew dolia św. aeeuszi ...   0.400447
# 5544   (Biblaż arstww kz kięga: Ew dolia św. aeeuszi ...   0.400484
# ...                                                  ...        ...
# 13259  (XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. P...   1.000000
# 21075  (XII NIEDZIELA ZWYKŁA, ROK C, 23. 06. 2019r. P...   1.000000
# 14835  (ZGROMADZENI NA ŚWIĘTEJ WIECZERZY\nList biskup...   1.000000
# 26448  (ŚW. MARIA MAGDALENA - patronka naszej parafii...   1.000000
# 18341  (Śluby Narodu\nSzczegóły Kategoria: DODATKI I ...   1.000000
#
# [1008 rows x 9 columns]

# %%
get_different(compare_df)
# Out:
#                name                                               text  words  \
# 24562   9401232.txt  Czym i dla kogo są N.O.? (Niedzielne Oczywisto...    455
# 9910   52343158.txt  Poniedziałek 12 grudnia 2022\n6:00\n+ Siostra ...    545
# 26736  97809564.txt  Data: 03.01.2023\nZamierzenia dydaktyczno – wy...    557
# 10170  53304492.txt  1. Ponawiamy zaproszenie J.E. Abp Metropolity ...    463
# 24582  94054701.txt  Bierzmowanie\nWarunki uczestniczenia w przygot...    428
# ...             ...                                                ...    ...
# 9815    5205030.txt  Parafia Mszano - Aktualności\nSzczegóły: | Pop...    927
# 25937  96593783.txt  Pewnego razu w Niemczech odbyły się rekolekcje...    886
# 4465    3060020.txt  Wymodlona i wywalczona wolność\nUmiłowani w Pa...   1570
# 18348  79025969.txt  LIST PASTERSKI BISKUPA PŁOCKIEGO PIOTRA LIBERY...   1338
# 20224  84312103.txt  Stolica Apostolska zaliczyła Szkaplerz do sakr...   1394
#
#        sentences  verbs_ratio  nouns_ratio  \
# 24562         36         0.11         0.24
# 9910          36         0.05         0.26
# 26736         34         0.06         0.38
# 10170         33         0.03         0.20
# 24582         35         0.06         0.34
# ...          ...          ...          ...
# 9815          51         0.06         0.26
# 25937         57         0.13         0.20
# 4465          75         0.07         0.29
# 18348         90         0.11         0.23
# 20224         68         0.08         0.30
#
#                                               median_str  \
# 24562  P  o                                          ...
# 9910   P  o                                          ...
# 26736  Wo  i                                         ...
# 10170  D ioo                                         ...
# 24582  D i                                           ...
# ...                                                  ...
# 9815   Parcii  szano  Op ublnii owzazeo:     eoezaiel...
# 25937  Aktualności Słowo na niedzielę\nSzczegóły Kate...
# 4465   W  orzi    IIaw a   Trlssi eana  aaruu ios yih...
# 18348  List iAAłyE SzE para ia  Prski EppWojaiuąca o2...
# 20224  Staiś   aeay dzaiosg S rty     iirae  li   nnl...
#
#                                                  lev_zip  lev_ratio
# 24562  (P  o                                         ...   0.084618
# 9910   (P  o                                         ...   0.102739
# 26736  (Wo  i                                        ...   0.103947
# 10170  (D ioo                                        ...   0.104923
# 24582  (D i                                          ...   0.107779
# ...                                                  ...        ...
# 9815   (Parcii  szano  Op ublnii owzazeo:     eoezaie...   0.395694
# 25937  (Aktualności Słowo na niedzielę\nSzczegóły Kat...   0.396972
# 4465   (W  orzi    IIaw a   Trlssi eana  aaruu ios yi...   0.397634
# 18348  (List iAAłyE SzE para ia  Prski EppWojaiuąca o...   0.397991
# 20224  (Staiś   aeay dzaiosg S rty     iirae  li   nn...   0.398814
#
# [7371 rows x 9 columns]

# %%
# It seems that shorter documents with small proper nouns count in our set are most likely to be duplicates.

fig = px.scatter_polar(
    compare_df,
    r=-compare_df['lev_ratio'],
    theta=compare_df['sentences'],
    color=compare_df['words'],
    color_continuous_scale=px.colors.cyclical.HSV,
    template="plotly_dark")
fig.show()
# Out:
# <div>                            <div id="4e91a1a6-a0a7-4fda-b3d3-6bd840835676" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e91a1a6-a0a7-4fda-b3d3-6bd840835676")) {                    Plotly.newPlot(                        "4e91a1a6-a0a7-4fda-b3d3-6bd840835676",                        [{"hovertemplate": "r=%{r}<br>sentences=%{theta}<br>words=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [4925, 1520, 4925, 465, 4754, 1098, 4925, 896, 481, 5564, 464, 691, 638, 458, 896, 1098, 464, 1294, 1991, 771, 648, 464, 4754, 4925, 536, 520, 512, 464, 539, 944, 531, 1294, 531, 464, 1294, 4925, 551, 563, 555, 5564, 622, 695, 855, 1155, 703, 4925, 462, 1294, 826, 4925, 772, 533, 560, 803, 548, 536, 10193, 474, 462, 1014, 518, 1098, 1155, 531, 487, 514, 618, 533, 928, 1275, 889, 862, 536, 5564, 581, 855, 531, 600, 631, 896, 702, 469, 524, 464, 449, 2568, 531, 5564, 588, 524, 513, 529, 464, 531, 1871, 513, 449, 1914, 1294, 526, 4925, 497, 531, 491, 529, 3314, 613, 555, 695, 502, 512, 1526, 927, 562, 717, 517, 889, 494, 501, 1414, 625, 633, 637, 480, 488, 622, 456, 529, 464, 510, 518, 928, 615, 5564, 531, 465, 494, 504, 5564, 695, 622, 679, 531, 533, 622, 732, 492, 487, 1212, 501, 546, 547, 587, 540, 1294, 523, 464, 455, 682, 438, 456, 530, 569, 530, 2655, 534, 588, 553, 607, 445, 544, 515, 487, 501, 543, 745, 774, 488, 531, 1955, 591, 615, 429, 573, 458, 1030, 546, 733, 444, 2655, 622, 530, 573, 10193, 512, 582, 546, 5564, 487, 677, 857, 464, 452, 803, 464, 896, 764, 497, 529, 633, 572, 463, 550, 510, 654, 948, 486, 599, 687, 3085, 396, 504, 803, 485, 545, 465, 2568, 565, 904, 416, 547, 944, 4925, 599, 896, 1014, 622, 672, 540, 560, 503, 508, 1121, 610, 547, 670, 487, 612, 4925, 529, 503,